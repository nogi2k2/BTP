# %% [markdown]
# # **FC-DNN**

# %%
# !pip install mne
# !pip install mne_bids
# !pip install pydub
# !pip install librosa==0.9.1
# Out:
# Collecting mne
#   Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.23.5)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.11.17)
# Installing collected packages: mne
# Successfully installed mne-1.6.1
# Collecting mne_bids
#   Downloading mne_bids-0.14-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: mne>=1.4 in /usr/local/lib/python3.10/dist-packages (from mne_bids) (1.6.1)
# Requirement already satisfied: numpy>=1.20.2 in /usr/local/lib/python3.10/dist-packages (from mne_bids) (1.23.5)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from mne_bids) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (1.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (23.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne>=1.4->mne_bids) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne>=1.4->mne_bids) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne>=1.4->mne_bids) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne>=1.4->mne_bids) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne>=1.4->mne_bids) (2.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne>=1.4->mne_bids) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.4->mne_bids) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.4->mne_bids) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.4->mne_bids) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.4->mne_bids) (2023.11.17)
# Installing collected packages: mne_bids
# Successfully installed mne_bids-0.14
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting librosa==0.9.1
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (3.0.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.9.1)
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (0.58.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1) (23.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.1) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.1) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.1) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.1) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa==0.9.1) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2023.11.17)
# Installing collected packages: resampy, librosa
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# Successfully installed librosa-0.9.1 resampy-0.4.2

# %%
import numpy as np
import mne
import pandas as pd
import mne_bids
import matplotlib.pyplot as plt
import soundfile as sf
import os
import pickle
from datetime import datetime, timedelta
from pydub import AudioSegment
import WaveGlow_functions
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, CSVLogger, ModelCheckpoint
import tensorflow as tf
import scipy.signal
import scipy.io as sio
import librosa

# %%
# do not use all GPU memory
import tensorflow.compat.v1 as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Helper functions**

# %%
#Small helper function to speed up the hilbert transform by extending the length of data to the next power of 2
hilbert3 = lambda x: scipy.signal.hilbert(
    x, scipy.fftpack.next_fast_len(len(x)), axis=0)[:len(x)]

# %%
def extractHG(data,
              sr,
              windowLength=0.05,
              frameshift=0.01,
              bandpass_min=1,
              bandpass_max=70):
    """
    Window data and extract frequency-band envelope using the hilbert transform

    Parameters
    ----------
    data: array (samples, channels)
        EEG time series
    sr: int
        Sampling rate of the data
    windowLength: float
        Length of window (in seconds) in which spectrogram will be calculated
    frameshift: float
        Shift (in seconds) after which next window will be extracted
    Returns
    ----------
    feat: array (windows, channels)
        Frequency-band feature matrix
    """
    #Linear detrend
    data = scipy.signal.detrend(data, axis=0)
    #Number of windows
    numWindows = int(
        np.floor((data.shape[0] - windowLength * sr) / (frameshift * sr)))
    #Filter High-Gamma Band
    # sos = scipy.signal.iirfilter(4, [70/(sr/2),170/(sr/2)],btype='bandpass',output='sos')
    sos = scipy.signal.iirfilter(
        4, [bandpass_min / (sr / 2), bandpass_max / (sr / 2)],
        btype='bandpass',
        output='sos')
    data = scipy.signal.sosfiltfilt(sos, data, axis=0)
    #Attenuate first harmonic of line noise
    # sos = scipy.signal.iirfilter(4, [98/(sr/2),102/(sr/2)],btype='bandstop',output='sos')
    # data = scipy.signal.sosfiltfilt(sos,data,axis=0)
    #Attenuate second harmonic of line noise
    # sos = scipy.signal.iirfilter(4, [148/(sr/2),152/(sr/2)],btype='bandstop',output='sos')
    # data = scipy.signal.sosfiltfilt(sos,data,axis=0)
    #Create feature space
    data = np.abs(hilbert3(data))
    feat = np.zeros((numWindows, data.shape[1]))
    for win in range(numWindows):
        start = int(np.floor((win * frameshift) * sr))
        stop = int(np.floor(start + windowLength * sr))
        feat[win, :] = np.mean(data[start:stop, :], axis=0)
    return feat

# %%
def stackFeatures(features, modelOrder=4, stepSize=5):
    """
    Add temporal context to each window by stacking neighboring feature vectors

    Parameters
    ----------
    features: array (windows, channels)
        Feature time series
    modelOrder: int
        Number of temporal context to include prior to and after current window
    stepSize: float
        Number of temporal context to skip for each next context (to compensate for frameshift)
    Returns
    ----------
    featStacked: array (windows, feat*(2*modelOrder+1))
        Stacked feature matrix
    """
    featStacked = np.zeros((features.shape[0] - (2 * modelOrder * stepSize),
                            (2 * modelOrder + 1) * features.shape[1]))
    for fNum, i in enumerate(
            range(modelOrder * stepSize,
                  features.shape[0] - modelOrder * stepSize)):
        ef = features[i - modelOrder * stepSize:i + modelOrder * stepSize +
                      1:stepSize, :]
        featStacked[
            fNum, :] = ef.flatten()  #Add 'F' if stacked the same as matlab
    return featStacked

# %%
# WaveGlow / Tacotron2 / STFT parameters for audio data
samplingFrequency = 22050
#samplingFrequency_EEG = 512 #sub 07
winL_EEG = 0.05
# frameshift_EEG = 0.01 # 10 ms
frameshift_EEG = 0.01  # 10 ms
frameshift_speech = 220  # 10ms
# modelOrder_EEG = 1
# modelOrder_EEG = 2
modelOrder_EEG = 4
# modelOrder_EEG = 10
stepSize_EEG = 5

# %%
stft = WaveGlow_functions.TacotronSTFT(filter_length=1024,
                                       hop_length=frameshift_speech,
                                       win_length=1024,
                                       n_mel_channels=80,
                                       sampling_rate=samplingFrequency,
                                       mel_fmin=0,
                                       mel_fmax=8000)
# Out:
# /content/WaveGlow_functions.py:136: FutureWarning: Pass size=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   fft_window = pad_center(fft_window, filter_length)
# /content/WaveGlow_functions.py:222: FutureWarning: Pass sr=22050, n_fft=1024, n_mels=80, fmin=0, fmax=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = librosa_mel_fn(

# %%
# # Load the original audio file
# y, sr = librosa.load('data/stimuli/6min.wav', sr=None)  # Load with original sampling rate

# print("Sampling rate before:", sr, "Hz")
# # Resample to 22050 Hz
# y_22050 = librosa.resample(y, orig_sr=sr, target_sr=22050)

# # Save the resampled audio to a new file
# sf.write('resampled_audio_22050Hz.wav', y_22050, 22050)

# # Use the resampled file in your processing pipeline
# wavfile = 'resampled_audio_22050Hz.wav'

# %%
# # Load the resampled audio file
# y, sr = librosa.load('resampled_audio_22050Hz.wav', sr=22050)

# # Shift the audio by 150 ms
# shift_ms = 150  # milliseconds
# shift_samples = int(sr * (shift_ms / 1000.0))  # Convert milliseconds to samples
# shifted_audio = np.pad(y, (shift_samples, 0), mode='constant', constant_values=(0, 0))

# # Save the shifted audio to a new file
# sf.write('shifted_audio_22050Hz.wav', shifted_audio, sr)

# %%
# Now you can compute the mel-spectrogram of the shifted audio
wavfile = 'shifted_audio_22050Hz.wav'
mel_data = WaveGlow_functions.get_mel(wavfile, stft)
mel_data_nonrot = mel_data
mel_data = np.fliplr(np.rot90(mel_data.data.numpy(), axes=(1, 0)))


# Print shapes and durations

# print("Original audio duration (seconds):", len(y) / sr)
# print("Shifted audio duration (seconds):", len(shifted_audio) / sr)

# %%
import matplotlib.pyplot as plt
import librosa.display

# Plot the waveform
# plt.figure(figsize=(10, 4))
# plt.plot(np.linspace(0, len(y) / sr, len(y)), y)
# plt.title('Waveform of Audio File')
# plt.xlabel('Time (seconds)')
# plt.ylabel('Amplitude')
# plt.show()

# Plot the mel-spectrogram before rotation and flipping
# plt.figure(figsize=(10, 4))
# librosa.display.specshow(librosa.power_to_db(mel_data_nonrot, ref=np.max), sr=sr, hop_length=512, y_axis='mel', x_axis='time')
# plt.colorbar(format='%+2.0f dB')
# plt.title('Mel-Spectrogram Before Transformation')
# plt.show()

# Plot the mel-spectrogram after rotation and flipping
plt.figure(figsize=(10, 4))
plt.imshow(mel_data, aspect='auto', origin='lower')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-Spectrogram After Transformation')
plt.xlabel('Time')
plt.ylabel('Mel Bin')
plt.show()

# %% [markdown]
# ### **Load Audio**

# %% [markdown]
# # Shift audio by 150 ms
# shifted_audio = audio._spawn(audio.raw_data,
#                              overrides={
#                                  'frame_rate': audio.frame_rate,
#                                  'frame_width': audio.sample_width
#                              })
# shifted_audio = shifted_audio._spawn(
#     shifted_audio.raw_data,
#     overrides={'frame_rate': shifted_audio.frame_rate + int(22050 * 0.15)})
# shifted_audio = shifted_audio.set_frame_rate(audio.frame_rate)
# shifted_audio = shifted_audio.set_channels(audio.channels)
#
# # Export shifted audio as WAV file
# shifted_audio.export('shifted_audio.wav', format='wav')
#
# #Load Audio
# wavfile = 'shifted_audio.wav'
# mel_data = WaveGlow_functions.get_mel(wavfile, stft)
# og_mel_data = mel_data
# mel_data = np.fliplr(np.rot90(mel_data.data.numpy(), axes=(1, 0)))
# og_mel_data_flipped= mel_data
# #mel_data = mel_data.data.numpy()
#
#
# print(mel_data.shape)
# # Print out the duration of the original and shifted audio
# print("Original audio duration:", audio.duration_seconds)
# print("Shifted audio duration:", shifted_audio.duration_seconds)

# %%
#Load Subjects
bids_dir = '/content/drive/MyDrive/btp'
subjects = mne_bids.get_entity_vals(bids_dir, 'subject')
#Choose subjects
# subject = '13'
subject = '38'
acquisition = 'clinical'
task = 'film'
datatype = 'ieeg'
session = 'iemu'

# %%
#load subject's channels
channels_path = mne_bids.BIDSPath(subject=subject,
                                  session=session,
                                  suffix='channels',
                                  extension='tsv',
                                  datatype=datatype,
                                  task=task,
                                  acquisition=acquisition,
                                  root=bids_dir)
# Out:
# <ipython-input-54-5ce59b791b62>:2: FutureWarning: extension should start with a period ".", but got: "tsv". Prepending "." to form: ".tsv". This will raise an exception starting with MNE-BIDS 0.12.
#   channels_path = mne_bids.BIDSPath(subject=subject,

# %%
channels = pd.read_csv(str(channels_path.match()[0]),
                       sep='\t',
                       header=0,
                       index_col=None)
#print(channels)

# %%
#set channel types
data_path = mne_bids.BIDSPath(subject=subject,
                              session=session,
                              suffix='ieeg',
                              extension='vhdr',
                              datatype=datatype,
                              task=task,
                              acquisition=acquisition,
                              root=bids_dir)
raw = mne.io.read_raw_brainvision(str(data_path.match()[0]),
                                  scale=1.0,
                                  preload=False,
                                  verbose=True)
raw.set_channel_types({
    ch_name:
    str(x).lower() if str(x).lower() in ['ecog', 'seeg', 'eeg'] else 'misc'
    for ch_name, x in zip(raw.ch_names, channels['type'].values)
})
raw.drop_channels([
    raw.ch_names[i] for i, j in enumerate(raw.get_channel_types())
    if j == 'misc'
])
# Out:
# <ipython-input-56-eb87faae4872>:2: FutureWarning: extension should start with a period ".", but got: "vhdr". Prepending "." to form: ".vhdr". This will raise an exception starting with MNE-BIDS 0.12.
#   data_path = mne_bids.BIDSPath(subject=subject,
# Extracting parameters from /content/drive/MyDrive/btp/sub-38/ses-iemu/ieeg/sub-38_ses-iemu_task-film_acq-clinical_run-1_ieeg.vhdr...
# Setting channel info structure...
# <ipython-input-56-eb87faae4872>:14: RuntimeWarning: The unit for channel(s) AH+, ECG+, EMG+, EMG2, Orb+ has changed from V to NA.
#   raw.set_channel_types({
# <RawBrainVision | sub-38_ses-iemu_task-film_acq-clinical_run-1_ieeg.eeg, 104 x 210206 (410.6 s), ~108 kB, data not loaded>

# %% [markdown]
# print(raw)

# %% [markdown]
# ### Discard Bad Channels

# %%
#bad channels
bad_channels = channels['name'][(channels['type'].isin(['ECOG', 'SEEG']))
                                & (channels['status'] == 'bad')].tolist()
raw.info['bads'].extend([ch for ch in bad_channels])
raw.drop_channels(raw.info['bads'])
# Out:
# <RawBrainVision | sub-38_ses-iemu_task-film_acq-clinical_run-1_ieeg.eeg, 101 x 210206 (410.6 s), ~105 kB, data not loaded>

# %% [markdown]
# ### Load Raw Data

# %%
raw.load_data()
# Out:
# Reading 0 ... 210205  =      0.000 ...   410.557 secs...
# <RawBrainVision | sub-38_ses-iemu_task-film_acq-clinical_run-1_ieeg.eeg, 101 x 210206 (410.6 s), ~162.1 MB, data loaded>

# %%
n_eeg_channels = int(raw.info['nchan'])  # for subject 01
print('n_eeg_channels', n_eeg_channels)
# raise
# Out:
# n_eeg_channels 101

# %% [markdown]
# ### Apply notch filter to remove line noise

# %%
raw.notch_filter(freqs=np.arange(50, 251, 50))
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 3381 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    1.2s
# <RawBrainVision | sub-38_ses-iemu_task-film_acq-clinical_run-1_ieeg.eeg, 101 x 210206 (410.6 s), ~162.1 MB, data loaded>

# %% [markdown]
# ### Apply common average reference to remove common noise and trends

# %%
#CAR
raw_car, _ = mne.set_eeg_reference(raw.copy(), 'average')
# Out:
# ECoG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('ECoG',) reference.

# %% [markdown]
# ### Read annotation with event markers

# %%
custom_mapping = {
    'Stimulus/music': 2,
    'Stimulus/speech': 1,
    'Stimulus/end task': 5
}  # 'Stimulus/task end' in laan
events, event_id = mne.events_from_annotations(raw_car,
                                               event_id=custom_mapping,
                                               use_rounding=False)
# Out:
# Used Annotations descriptions: ['Stimulus/end task', 'Stimulus/music', 'Stimulus/speech']

# %%
#plotting
raw_car.plot(n_channels=30, scalings='auto', duration=20, start=109)
plt.show()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# raise

# %%
#get EEG SR
n_melspec = 80
samplingFrequency_EEG = raw_car.info['sfreq']

# %%
eeg=raw_car.get_data()


#create a copy taht we crop
raw_car_cut = raw_car.get_data()
print(raw_car_cut.shape)
#(n_channels, n_times)
# Out:
# (101, 210206)

# %%
print('before cut: ', raw_car._data.shape, mel_data.shape)

raw_car_cut = np.empty((n_eeg_channels, 0))
mel_data_cut = np.empty((0, n_melspec))

# for i in range(6):
for i in range(6):
    start_time = events[2 * i + 1, 0] / raw_car.info['sfreq']
    end_time = events[2 * i + 2, 0] / raw_car.info['sfreq']
    start_idx, end_idx = raw_car.time_as_index([start_time, end_time])
    print(i, 'iEEG index', start_idx, end_idx, end_idx - start_idx)
    n_frames_per_sec = int(1 / frameshift_EEG)
    print(i, 'melspec index', (2 * i + 1) * 30 * n_frames_per_sec,
          (2 * i + 2) * 30 * n_frames_per_sec,
          (2 * i + 2) * 30 * n_frames_per_sec -
          (2 * i + 1) * 30 * n_frames_per_sec)
    # raw_car_cut1 = raw_car._data[:, start_idx:end_idx]
    raw_car_cut1 = eeg[:, start_idx:end_idx]
    raw_car_cut = np.append(raw_car_cut, raw_car_cut1, axis=1)
    mel_data_cut1 = mel_data[(2 * i + 1) * 30 * n_frames_per_sec:(2 * i + 2) *
                             30 * n_frames_per_sec]
    mel_data_cut = np.append(mel_data_cut, mel_data_cut1, axis=0)
# raise
mel_data = mel_data_cut

print('after cut: ', raw_car_cut.shape, mel_data.shape)
# raise
#praat
# Out:
# before cut:  (101, 210206) (17956, 80)
# 0 iEEG index 22623 37983 15360
# 0 melspec index 3000 6000 3000
# 1 iEEG index 53375 68735 15360
# 1 melspec index 9000 12000 3000
# 2 iEEG index 84095 99455 15360
# 2 melspec index 15000 18000 3000
# 3 iEEG index 114815 130175 15360
# 3 melspec index 21000 24000 3000
# 4 iEEG index 145535 160895 15360
# 4 melspec index 27000 30000 3000
# 5 iEEG index 176255 191615 15360
# 5 melspec index 33000 36000 3000
# after cut:  (101, 92160) (8956, 80)

# %%
#get EEG SR
samplingFrequency_EEG = raw_car.info['sfreq']

# Calculate the length of the signal
length = raw_car_cut.shape[1] / samplingFrequency_EEG

print("The length of the EEG signal is", length, "s")
print(samplingFrequency_EEG)
# Out:
# The length of the EEG signal is 180.0 s
# 512.0

# %% [markdown]
# ### Prepare Data for training

# %% [markdown]
# ### Extract features

# %%
#Extract HG features
print('calculating Hilbert...', raw_car_cut.shape)
# eeg_fft = np.empty((n_max_frames, n_freq_bands, n_eeg_channels * (2 * modelOrder_EEG + 1) ))
# feat_Hilbert_1 = extractHG(raw_car_cut,samplingFrequency_EEG, windowLength=winL_EEG,frameshift=frameshift_EEG, bandpass_min=1, bandpass_max=200)
feat_Hilbert_1 = extractHG(np.rot90(raw_car_cut),
                           samplingFrequency_EEG,
                           windowLength=winL_EEG,
                           frameshift=frameshift_EEG,
                           bandpass_min=1,
                           bandpass_max=70)
# feat_Hilbert_2 = extractHG(np.rot90(current_raw_eeg_data),samplingFrequency_EEG, windowLength=winL_EEG,frameshift=frameshift_EEG, bandpass_min=51, bandpass_max=100)
# feat_Hilbert_3 = extractHG(np.rot90(current_raw_eeg_data),samplingFrequency_EEG, windowLength=winL_EEG,frameshift=frameshift_EEG, bandpass_min=101, bandpass_max=150)
# feat_Hilbert_4 = extractHG(np.rot90(current_raw_eeg_data),samplingFrequency_EEG, windowLength=winL_EEG,frameshift=frameshift_EEG, bandpass_min=151, bandpass_max=200)
# Out:
# calculating Hilbert... (101, 92160)

# %%
#Stack features
feat_Hilbert_1 = stackFeatures(feat_Hilbert_1,
                               modelOrder=modelOrder_EEG,
                               stepSize=stepSize_EEG)

# %%
plt.subplot(211)
plt.imshow(np.rot90(feat_Hilbert_1), aspect='auto')

plt.subplot(212)
plt.imshow(np.rot90(mel_data), aspect='auto')
plt.show()

eeg = feat_Hilbert_1
print('mel & iEEG: ', mel_data.shape, feat_Hilbert_1.shape)
# Out:
# mel & iEEG:  (8956, 80) (17955, 909)

# %%
min_len = np.min((len(eeg), len(mel_data)))
eeg = eeg[0:min_len]
mel_data = mel_data[0:min_len]

# %%
print('mel & iEEG: ', mel_data.shape, eeg.shape)
# Out:
# mel & iEEG:  (8956, 80) (8956, 909)

# %%
train_index = np.arange(0, int(0.8 * eeg.shape[0]))
test_index = np.arange(int(0.8 * eeg.shape[0]), eeg.shape[0])

# %%
# train-validation-test split
eeg_train = eeg[0:int(len(eeg) * 0.8)]
eeg_valid = eeg[int(len(eeg) * 0.8):int(len(eeg) * 0.9)]
eeg_test = eeg[int(len(eeg) * 0.9):]

# %%
melspec_train = mel_data[0:int(len(mel_data) * 0.8)]
melspec_valid = mel_data[int(len(mel_data) * 0.8):int(len(mel_data) * 0.9)]
melspec_test = mel_data[int(len(mel_data) * 0.9):]

# %%
# scale input to [0-1]
eeg_scaler = MinMaxScaler()
# eeg_scaler = StandardScaler(with_mean=True, with_std=True)
eeg_train_scaled = eeg_scaler.fit_transform(eeg_train)
eeg_valid_scaled = eeg_scaler.transform(eeg_valid)
eeg_test_scaled = eeg_scaler.transform(eeg_test)

# %%
# scale outpit mel-spectrogram data to zero mean, unit variances
melspec_scaler = StandardScaler(with_mean=True, with_std=True)
melspec_train_scaled = melspec_scaler.fit_transform(melspec_train)
melspec_valid_scaled = melspec_scaler.transform(melspec_valid)
melspec_test_scaled = melspec_scaler.transform(melspec_test)

# %%
import matplotlib.pyplot as plt

# Assuming mel_data is your original mel-spectrogram and melspec_test_scaled is the scaled version
# Also assuming both are NumPy arrays

# Plot original mel-spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(mel_data.T, aspect='auto', origin='lower')
plt.title('Original Mel-Spectrogram')
plt.xlabel('Time')
plt.ylabel('Mel Bin')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()

# Plot scaled mel-spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(melspec_test_scaled.T, aspect='auto', origin='lower')
plt.title('Scaled Mel-Spectrogram')
plt.xlabel('Time')
plt.ylabel('Mel Bin')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### FC-DNN

# %%
# 5 hidden layers, with 1000 neuron on each layer
model = Sequential()
model.add(
    Dense(1000,
          input_dim=eeg_train_scaled.shape[1],
          kernel_initializer='normal',
          activation='relu'))
model.add(
    Dense(1000,
          input_dim=eeg_train_scaled.shape[1],
          kernel_initializer='normal',
          activation='relu'))
model.add(
    Dense(1000,
          input_dim=eeg_train_scaled.shape[1],
          kernel_initializer='normal',
          activation='relu'))
model.add(Dense(80, kernel_initializer='normal', activation='linear'))

# %%
# compile model
model.compile(loss='mean_squared_error',
              metrics=['mean_squared_error'],
              optimizer='adam')
earlystopper = EarlyStopping(monitor='val_mean_squared_error',
                             min_delta=0.0001,
                             patience=5,
                             verbose=1,
                             mode='auto')

if not (os.path.isdir('models_iEEG_to_melspec/')):
    os.mkdir('models_iEEG_to_melspec/')

# %%
# early stopping to avoid over-training
# csv logger
current_date = '{date:%Y-%m-%d_%H-%M-%S}'.format(date=datetime.now())
print(current_date)
# n_eeg_channels * (2 * modelOrder_EEG + 1)
model_name = 'models_iEEG_to_melspec/iEEG-Hilbert_to_melspec_DNN_modelOrder-' + str(
    modelOrder_EEG).zfill(
        2) + '_freqBands-1_' + '_sub' + subject + '_' + current_date
logger = CSVLogger(model_name + '.csv', append=True, separator=';')
checkp = ModelCheckpoint(model_name + '_weights_best.h5',
                         monitor='val_loss',
                         verbose=1,
                         save_best_only=True,
                         mode='min')
# Out:
# 2024-02-04_12-21-54

# %% [markdown]
# serialize scalers to pickle
# pickle.dump(eeg_scaler, open(model_name + '_eeg_scaler.sav', 'wb'))
# pickle.dump(melspec_scaler, open(model_name + '_melspec_scaler.sav', 'wb'))

# %% [markdown]
# ### Run training

# %%
history = model.fit(
    eeg_train_scaled,
    melspec_train_scaled,
    epochs=100,
    batch_size=32,
    shuffle=True,
    verbose=1,
    callbacks=[logger, checkp],
    validation_split=0.9,
    validation_data=(eeg_valid_scaled, melspec_valid_scaled),
)
# Out:
# Epoch 1/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.9013 - mean_squared_error: 0.9013
# Epoch 1: val_loss improved from inf to 1.18991, saving model to models_iEEG_to_melspec/iEEG-Hilbert_to_melspec_DNN_modelOrder-04_freqBands-1__sub38_2024-02-04_12-21-54_weights_best.h5
# 224/224 [==============================] - 2s 5ms/step - loss: 0.9006 - mean_squared_error: 0.9006 - val_loss: 1.1899 - val_mean_squared_error: 1.1899
# Epoch 2/100
#  13/224 [>.............................] - ETA: 0s - loss: 0.7499 - mean_squared_error: 0.7499
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 218/224 [============================>.] - ETA: 0s - loss: 0.6687 - mean_squared_error: 0.6687
# Epoch 2: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.6664 - mean_squared_error: 0.6664 - val_loss: 1.9159 - val_mean_squared_error: 1.9159
# Epoch 3/100
# 222/224 [============================>.] - ETA: 0s - loss: 0.5158 - mean_squared_error: 0.5158
# Epoch 3: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.5167 - mean_squared_error: 0.5167 - val_loss: 1.8754 - val_mean_squared_error: 1.8754
# Epoch 4/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.4169 - mean_squared_error: 0.4169
# Epoch 4: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.4167 - mean_squared_error: 0.4167 - val_loss: 1.4319 - val_mean_squared_error: 1.4319
# Epoch 5/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.3304 - mean_squared_error: 0.3304
# Epoch 5: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.3292 - mean_squared_error: 0.3292 - val_loss: 1.8778 - val_mean_squared_error: 1.8778
# Epoch 6/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.2804 - mean_squared_error: 0.2804
# Epoch 6: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.2796 - mean_squared_error: 0.2796 - val_loss: 1.8609 - val_mean_squared_error: 1.8609
# Epoch 7/100
# 220/224 [============================>.] - ETA: 0s - loss: 0.2465 - mean_squared_error: 0.2465
# Epoch 7: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.2464 - mean_squared_error: 0.2464 - val_loss: 1.6044 - val_mean_squared_error: 1.6044
# Epoch 8/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.2072 - mean_squared_error: 0.2072
# Epoch 8: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.2068 - mean_squared_error: 0.2068 - val_loss: 1.6338 - val_mean_squared_error: 1.6338
# Epoch 9/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.1811 - mean_squared_error: 0.1811
# Epoch 9: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1815 - mean_squared_error: 0.1815 - val_loss: 1.5387 - val_mean_squared_error: 1.5387
# Epoch 10/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.1636 - mean_squared_error: 0.1636
# Epoch 10: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1635 - mean_squared_error: 0.1635 - val_loss: 1.9087 - val_mean_squared_error: 1.9087
# Epoch 11/100
# 221/224 [============================>.] - ETA: 0s - loss: 0.1432 - mean_squared_error: 0.1432
# Epoch 11: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1432 - mean_squared_error: 0.1432 - val_loss: 1.6531 - val_mean_squared_error: 1.6531
# Epoch 12/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.1332 - mean_squared_error: 0.1332
# Epoch 12: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1331 - mean_squared_error: 0.1331 - val_loss: 1.9024 - val_mean_squared_error: 1.9024
# Epoch 13/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.1228 - mean_squared_error: 0.1228
# Epoch 13: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1226 - mean_squared_error: 0.1226 - val_loss: 1.5479 - val_mean_squared_error: 1.5479
# Epoch 14/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.1098 - mean_squared_error: 0.1098
# Epoch 14: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1099 - mean_squared_error: 0.1099 - val_loss: 1.7894 - val_mean_squared_error: 1.7894
# Epoch 15/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.1108 - mean_squared_error: 0.1108
# Epoch 15: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 1.7550 - val_mean_squared_error: 1.7550
# Epoch 16/100
# 220/224 [============================>.] - ETA: 0s - loss: 0.1032 - mean_squared_error: 0.1032
# Epoch 16: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.1033 - mean_squared_error: 0.1033 - val_loss: 1.6765 - val_mean_squared_error: 1.6765
# Epoch 17/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0942 - mean_squared_error: 0.0942
# Epoch 17: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0942 - mean_squared_error: 0.0942 - val_loss: 1.7529 - val_mean_squared_error: 1.7529
# Epoch 18/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.0975 - mean_squared_error: 0.0975
# Epoch 18: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0973 - mean_squared_error: 0.0973 - val_loss: 1.5987 - val_mean_squared_error: 1.5987
# Epoch 19/100
# 211/224 [===========================>..] - ETA: 0s - loss: 0.0891 - mean_squared_error: 0.0891
# Epoch 19: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0895 - mean_squared_error: 0.0895 - val_loss: 1.5998 - val_mean_squared_error: 1.5998
# Epoch 20/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0898 - mean_squared_error: 0.0898
# Epoch 20: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0902 - mean_squared_error: 0.0902 - val_loss: 1.8238 - val_mean_squared_error: 1.8238
# Epoch 21/100
# 222/224 [============================>.] - ETA: 0s - loss: 0.0845 - mean_squared_error: 0.0845
# Epoch 21: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 1.5664 - val_mean_squared_error: 1.5664
# Epoch 22/100
# 221/224 [============================>.] - ETA: 0s - loss: 0.0766 - mean_squared_error: 0.0766
# Epoch 22: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0767 - mean_squared_error: 0.0767 - val_loss: 1.6664 - val_mean_squared_error: 1.6664
# Epoch 23/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0755 - mean_squared_error: 0.0755
# Epoch 23: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0756 - mean_squared_error: 0.0756 - val_loss: 1.4725 - val_mean_squared_error: 1.4725
# Epoch 24/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0714 - mean_squared_error: 0.0714
# Epoch 24: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0712 - mean_squared_error: 0.0712 - val_loss: 1.5180 - val_mean_squared_error: 1.5180
# Epoch 25/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.0665 - mean_squared_error: 0.0665
# Epoch 25: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0667 - mean_squared_error: 0.0667 - val_loss: 1.5071 - val_mean_squared_error: 1.5071
# Epoch 26/100
# 222/224 [============================>.] - ETA: 0s - loss: 0.0674 - mean_squared_error: 0.0674
# Epoch 26: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0674 - mean_squared_error: 0.0674 - val_loss: 1.4213 - val_mean_squared_error: 1.4213
# Epoch 27/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0689 - mean_squared_error: 0.0689
# Epoch 27: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 1.5519 - val_mean_squared_error: 1.5519
# Epoch 28/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.0645 - mean_squared_error: 0.0645
# Epoch 28: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 1.4514 - val_mean_squared_error: 1.4514
# Epoch 29/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0609 - mean_squared_error: 0.0609
# Epoch 29: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 1.4089 - val_mean_squared_error: 1.4089
# Epoch 30/100
# 221/224 [============================>.] - ETA: 0s - loss: 0.0669 - mean_squared_error: 0.0669
# Epoch 30: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0680 - mean_squared_error: 0.0680 - val_loss: 1.7016 - val_mean_squared_error: 1.7016
# Epoch 31/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0909 - mean_squared_error: 0.0909
# Epoch 31: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0895 - mean_squared_error: 0.0895 - val_loss: 1.5428 - val_mean_squared_error: 1.5428
# Epoch 32/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.0574 - mean_squared_error: 0.0574
# Epoch 32: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 1.4598 - val_mean_squared_error: 1.4598
# Epoch 33/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0527 - mean_squared_error: 0.0527
# Epoch 33: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0527 - mean_squared_error: 0.0527 - val_loss: 1.5440 - val_mean_squared_error: 1.5440
# Epoch 34/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0650 - mean_squared_error: 0.0650
# Epoch 34: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0648 - mean_squared_error: 0.0648 - val_loss: 1.4544 - val_mean_squared_error: 1.4544
# Epoch 35/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0525 - mean_squared_error: 0.0525
# Epoch 35: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0530 - mean_squared_error: 0.0530 - val_loss: 1.3923 - val_mean_squared_error: 1.3923
# Epoch 36/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0519 - mean_squared_error: 0.0519
# Epoch 36: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0519 - mean_squared_error: 0.0519 - val_loss: 1.4157 - val_mean_squared_error: 1.4157
# Epoch 37/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0512 - mean_squared_error: 0.0512
# Epoch 37: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 1.5725 - val_mean_squared_error: 1.5725
# Epoch 38/100
# 210/224 [===========================>..] - ETA: 0s - loss: 0.0480 - mean_squared_error: 0.0480
# Epoch 38: val_loss did not improve from 1.18991
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0487 - mean_squared_error: 0.0487 - val_loss: 1.4895 - val_mean_squared_error: 1.4895
# Epoch 39/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0532 - mean_squared_error: 0.0532
# Epoch 39: val_loss did not improve from 1.18991
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 1.4512 - val_mean_squared_error: 1.4512
# Epoch 40/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0549 - mean_squared_error: 0.0549
# Epoch 40: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 1.5593 - val_mean_squared_error: 1.5593
# Epoch 41/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0472 - mean_squared_error: 0.0472
# Epoch 41: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 1.5607 - val_mean_squared_error: 1.5607
# Epoch 42/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0467 - mean_squared_error: 0.0467
# Epoch 42: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 1.4484 - val_mean_squared_error: 1.4484
# Epoch 43/100
# 221/224 [============================>.] - ETA: 0s - loss: 0.0496 - mean_squared_error: 0.0496
# Epoch 43: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 1.5785 - val_mean_squared_error: 1.5785
# Epoch 44/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0475 - mean_squared_error: 0.0475
# Epoch 44: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0475 - mean_squared_error: 0.0475 - val_loss: 1.3948 - val_mean_squared_error: 1.3948
# Epoch 45/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.0478 - mean_squared_error: 0.0478
# Epoch 45: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 1.3665 - val_mean_squared_error: 1.3665
# Epoch 46/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0468 - mean_squared_error: 0.0468
# Epoch 46: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 1.6184 - val_mean_squared_error: 1.6184
# Epoch 47/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0397 - mean_squared_error: 0.0397
# Epoch 47: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 1.4788 - val_mean_squared_error: 1.4788
# Epoch 48/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.0378 - mean_squared_error: 0.0378
# Epoch 48: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 1.6214 - val_mean_squared_error: 1.6214
# Epoch 49/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0387 - mean_squared_error: 0.0387
# Epoch 49: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 1.5733 - val_mean_squared_error: 1.5733
# Epoch 50/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0436 - mean_squared_error: 0.0436
# Epoch 50: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 1.4895 - val_mean_squared_error: 1.4895
# Epoch 51/100
# 222/224 [============================>.] - ETA: 0s - loss: 0.0414 - mean_squared_error: 0.0414
# Epoch 51: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0415 - mean_squared_error: 0.0415 - val_loss: 1.3940 - val_mean_squared_error: 1.3940
# Epoch 52/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0429 - mean_squared_error: 0.0429
# Epoch 52: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 1.5156 - val_mean_squared_error: 1.5156
# Epoch 53/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0388 - mean_squared_error: 0.0388
# Epoch 53: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 1.5293 - val_mean_squared_error: 1.5293
# Epoch 54/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0357 - mean_squared_error: 0.0357
# Epoch 54: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 1.3058 - val_mean_squared_error: 1.3058
# Epoch 55/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0381 - mean_squared_error: 0.0381
# Epoch 55: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 1.3692 - val_mean_squared_error: 1.3692
# Epoch 56/100
# 221/224 [============================>.] - ETA: 0s - loss: 0.0399 - mean_squared_error: 0.0399
# Epoch 56: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 1.4562 - val_mean_squared_error: 1.4562
# Epoch 57/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.0465 - mean_squared_error: 0.0465
# Epoch 57: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0462 - mean_squared_error: 0.0462 - val_loss: 1.3374 - val_mean_squared_error: 1.3374
# Epoch 58/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0409 - mean_squared_error: 0.0409
# Epoch 58: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0409 - mean_squared_error: 0.0409 - val_loss: 1.3683 - val_mean_squared_error: 1.3683
# Epoch 59/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0358 - mean_squared_error: 0.0358
# Epoch 59: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 1.3945 - val_mean_squared_error: 1.3945
# Epoch 60/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0354 - mean_squared_error: 0.0354
# Epoch 60: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 1.4831 - val_mean_squared_error: 1.4831
# Epoch 61/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 61: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 1.4936 - val_mean_squared_error: 1.4936
# Epoch 62/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0346 - mean_squared_error: 0.0346
# Epoch 62: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 1.4422 - val_mean_squared_error: 1.4422
# Epoch 63/100
# 210/224 [===========================>..] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0320
# Epoch 63: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 1.4333 - val_mean_squared_error: 1.4333
# Epoch 64/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.0331 - mean_squared_error: 0.0331
# Epoch 64: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 1.3151 - val_mean_squared_error: 1.3151
# Epoch 65/100
# 220/224 [============================>.] - ETA: 0s - loss: 0.0316 - mean_squared_error: 0.0316
# Epoch 65: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 1.5232 - val_mean_squared_error: 1.5232
# Epoch 66/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0359 - mean_squared_error: 0.0359
# Epoch 66: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 1.4892 - val_mean_squared_error: 1.4892
# Epoch 67/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0382 - mean_squared_error: 0.0382
# Epoch 67: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 1.6391 - val_mean_squared_error: 1.6391
# Epoch 68/100
# 220/224 [============================>.] - ETA: 0s - loss: 0.0394 - mean_squared_error: 0.0394
# Epoch 68: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 1.3163 - val_mean_squared_error: 1.3163
# Epoch 69/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0331 - mean_squared_error: 0.0331
# Epoch 69: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 1.3540 - val_mean_squared_error: 1.3540
# Epoch 70/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 70: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 1.4416 - val_mean_squared_error: 1.4416
# Epoch 71/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0276 - mean_squared_error: 0.0276
# Epoch 71: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 1.4591 - val_mean_squared_error: 1.4591
# Epoch 72/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0289 - mean_squared_error: 0.0289
# Epoch 72: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 1.3884 - val_mean_squared_error: 1.3884
# Epoch 73/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0318 - mean_squared_error: 0.0318
# Epoch 73: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 1.4369 - val_mean_squared_error: 1.4369
# Epoch 74/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0377 - mean_squared_error: 0.0377
# Epoch 74: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 1.2290 - val_mean_squared_error: 1.2290
# Epoch 75/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0345 - mean_squared_error: 0.0345
# Epoch 75: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 1.4556 - val_mean_squared_error: 1.4556
# Epoch 76/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 76: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 1.2982 - val_mean_squared_error: 1.2982
# Epoch 77/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0249 - mean_squared_error: 0.0249
# Epoch 77: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 1.4524 - val_mean_squared_error: 1.4524
# Epoch 78/100
# 220/224 [============================>.] - ETA: 0s - loss: 0.0262 - mean_squared_error: 0.0262
# Epoch 78: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 1.5063 - val_mean_squared_error: 1.5063
# Epoch 79/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 79: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 1.4834 - val_mean_squared_error: 1.4834
# Epoch 80/100
# 211/224 [===========================>..] - ETA: 0s - loss: 0.0341 - mean_squared_error: 0.0341
# Epoch 80: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 1.4389 - val_mean_squared_error: 1.4389
# Epoch 81/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 81: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 1.5014 - val_mean_squared_error: 1.5014
# Epoch 82/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0303 - mean_squared_error: 0.0303
# Epoch 82: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 1.4341 - val_mean_squared_error: 1.4341
# Epoch 83/100
# 212/224 [===========================>..] - ETA: 0s - loss: 0.0250 - mean_squared_error: 0.0250
# Epoch 83: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 1.4337 - val_mean_squared_error: 1.4337
# Epoch 84/100
# 219/224 [============================>.] - ETA: 0s - loss: 0.0291 - mean_squared_error: 0.0291
# Epoch 84: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 1.4433 - val_mean_squared_error: 1.4433
# Epoch 85/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0326 - mean_squared_error: 0.0326
# Epoch 85: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 1.5449 - val_mean_squared_error: 1.5449
# Epoch 86/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 86: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 1.3766 - val_mean_squared_error: 1.3766
# Epoch 87/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0239 - mean_squared_error: 0.0239
# Epoch 87: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 1.3910 - val_mean_squared_error: 1.3910
# Epoch 88/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0232 - mean_squared_error: 0.0232
# Epoch 88: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 1.4527 - val_mean_squared_error: 1.4527
# Epoch 89/100
# 224/224 [==============================] - ETA: 0s - loss: 0.0246 - mean_squared_error: 0.0246
# Epoch 89: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 1.4628 - val_mean_squared_error: 1.4628
# Epoch 90/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 90: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 1.3677 - val_mean_squared_error: 1.3677
# Epoch 91/100
# 216/224 [===========================>..] - ETA: 0s - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 91: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 1.4492 - val_mean_squared_error: 1.4492
# Epoch 92/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0252 - mean_squared_error: 0.0252
# Epoch 92: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 1.3705 - val_mean_squared_error: 1.3705
# Epoch 93/100
# 213/224 [===========================>..] - ETA: 0s - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 93: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 1.3992 - val_mean_squared_error: 1.3992
# Epoch 94/100
# 223/224 [============================>.] - ETA: 0s - loss: 0.0300 - mean_squared_error: 0.0300
# Epoch 94: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 1.3109 - val_mean_squared_error: 1.3109
# Epoch 95/100
# 215/224 [===========================>..] - ETA: 0s - loss: 0.0279 - mean_squared_error: 0.0279
# Epoch 95: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 1.3340 - val_mean_squared_error: 1.3340
# Epoch 96/100
# 217/224 [============================>.] - ETA: 0s - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 96: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 6ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 1.3560 - val_mean_squared_error: 1.3560
# Epoch 97/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0275 - mean_squared_error: 0.0275
# Epoch 97: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 1.3111 - val_mean_squared_error: 1.3111
# Epoch 98/100
# 214/224 [===========================>..] - ETA: 0s - loss: 0.0281 - mean_squared_error: 0.0281
# Epoch 98: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 1.4261 - val_mean_squared_error: 1.4261
# Epoch 99/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 99: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 1.3746 - val_mean_squared_error: 1.3746
# Epoch 100/100
# 218/224 [============================>.] - ETA: 0s - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 100: val_loss did not improve from 1.18991
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 1.4100 - val_mean_squared_error: 1.4100

# %%
# save model
model_json = model.to_json()
with open(model_name + '_model.json', "w") as json_file:
    json_file.write(model_json)

# here the training of the DNN is finished
# load back best weights
model.load_weights(model_name + '_weights_best.h5')
# remove model file
# os.remove(model_name + '_weights_best.h5')

# %% [markdown]
# ### Visualize predicted melspectogram

# %%
# melspec_predicted = model.predict(eeg_test_scaled[0:500])
melspec_predicted = model.predict(eeg_test_scaled[0:1000])
# melspec_predicted = melspec_predicted[0:500]
# test_melspec = test_melspec[]

#best stuff

best_val_mse = min(history.history['val_mean_squared_error'])
print(f'Best validation MSE: {best_val_mse:.4f}')

min_train_loss = min(history.history['loss'])
print(f'Minimum training loss: {min_train_loss:.4f}')

fig, axs = plt.subplots(3, 1, figsize=(10, 10))
axs[0].imshow(np.rot90(eeg_test_scaled[0:1000]), aspect='auto')
axs[0].set_title('EEG Test Scaled')
axs[1].imshow(np.rot90(melspec_test_scaled[0:1000]), aspect='auto')
axs[1].set_title('Mel-Spectrogram Test Scaled')
axs[2].imshow(np.rot90(melspec_predicted[0:1000]), aspect='auto')
axs[2].set_title('Mel-Spectrogram Predicted')
plt.suptitle(
    f'FC-DNN results (scaled) for subject {subject}\nBest validation MSE: {best_val_mse:.4f}, Minimum training loss: {min_train_loss:.4f}'
)
plt.subplots_adjust(hspace=0.4)

plt.savefig(model_name + '_EEG_scaled_plots.png')
plt.show()
# Out:
# 28/28 [==============================] - 0s 3ms/step
# Best validation MSE: 1.1899
# Minimum training loss: 0.0226

# %% [markdown]
# ### Audio synth

# %%
# Provide the actual mel spectrogram (melspec_predicted) and sampling frequency (samplingFrequency) from your FC-DNN output
samplingFrequency = 16000

# Convert mel spectrogram to audio using Griffin-Lim algorithm
audio = librosa.feature.inverse.mel_to_audio(melspec_predicted,
                                             sr=samplingFrequency)

# Save the audio to a WAV file
output_file = subject + ' predicted_audio_fc-DNN.wav'
sf.write(output_file, audio, samplingFrequency)
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   return f(*args, **kwargs)

# %% [markdown]
# # **Metrics and Scores**

# %%
import numpy as np
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error
from scipy.signal import find_peaks
from scipy.stats import wasserstein_distance
from scipy.spatial.distance import cosine
from scipy.special import kl_div
from scipy.stats import pearsonr

ground_truth_mel_spectrogram = melspec_test_scaled[0:1000]
predicted_mel_spectrogram = melspec_predicted[0:1000]

ssim_score = ssim(ground_truth_mel_spectrogram, predicted_mel_spectrogram)
mse = mean_squared_error(ground_truth_mel_spectrogram, predicted_mel_spectrogram)
psnr = 10 * np.log10(1.0 / mse)
cosine_similarity = 1 - cosine(ground_truth_mel_spectrogram.flatten(), predicted_mel_spectrogram.flatten())
kl_divergence = kl_div(ground_truth_mel_spectrogram.flatten(), predicted_mel_spectrogram.flatten())

pearson_corr, _ = pearsonr(ground_truth_mel_spectrogram.flatten(), predicted_mel_spectrogram.flatten())

print(f"SSIM: {ssim_score}\nMSE: {mse}\nPSNR: {psnr}\nCosine Similarity: {cosine_similarity}\nKL Divergence: {kl_divergence}\nPearson Correlation: {pearson_corr}")
# Out:
# SSIM: 0.0041237471028173385
# MSE: 1.1990440242827356
# PSNR: -0.7883512901382804
# Cosine Similarity: -0.03990827065003444
# KL Divergence: [       inf        inf 0.25197178 ...        inf        inf        inf]
# Pearson Correlation: -0.03349594570816805
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:348: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)

# %%
import matplotlib.pyplot as plt

training_loss = history.history['mean_squared_error']
validation_loss = history.history['val_mean_squared_error']

epochs = range(1, len(training_loss) + 1)

plt.plot(epochs, training_loss, 'bo', label='Training Loss')
plt.plot(epochs, validation_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
